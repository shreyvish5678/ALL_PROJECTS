# %%
import numpy as np
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
deploy_model = tf.keras.models.load_model('train_model.h5')

# %%
img = Image.open('input_image.jpg')
img = img.resize((32, 32))
img = img.convert('RGB')
np_img = np.array(img)
plt.imshow(np_img)
plt.show()
np_img = np.array([np_img])
np_img = np_img.astype('float32') / 255.0

# %%
prediction = deploy_model.predict(np_img)
print(f'There is a {round(prediction[0][0]*100, 2)}% chance that the crop is fresh!')
# Out:
# 1/1 [==============================] - 1s 569ms/step
# There is a 98.8% chance that the crop is fresh!
